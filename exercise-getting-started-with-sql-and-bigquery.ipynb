# %% [markdown]
# **[SQL Home Page](https://www.kaggle.com/learn/intro-to-sql)**
#
# ---

# %%
# Following along from the lecture since the lecture isn't interactive
from google.cloud import bigquery

# %%
# Create Client object to run methods to retrieve things
client = bigquery.Client()

# %%
print(type(client))

# %%
# dataset reference object to pass to get_dataset function 
hn_dataset_ref = client.dataset("hacker_news", project="bigquery-public-data")

# fetch data set and bind to a variable
hn_dataset = client.get_dataset(hn_dataset_ref)

# %%
print(type(hn_dataset_ref))

# %%
print(type(hn_dataset))

# %%
# list tables in data set which is a collection of tables

print(type(client.list_tables(hn_dataset)))

# %%
hn_tables_list = list(client.list_tables(hn_dataset))

for i in hn_tables_list: print(i.table_id)

# %%
# Create reference to a single table and fetch it
full_table_ref = hn_dataset_ref.table("full")

full_table = client.get_table(full_table_ref)

# %%
# Use for loop to more easily see the column details seperated by newline char
# fields are:
# name, datatype, mode (default = nullable, allows null values), description
full_table_schema_list = list(full_table.schema)

for i in full_table_schema_list: print(i)

# %%
# convert to dataframe first 5 
first_five = client.list_rows(full_table, max_results=5).to_dataframe()
print(type(first_five))
first_five

# %%
# look only at first column 
client.list_rows(full_table, selected_fields=full_table.schema[:1],max_results=5).to_dataframe()

# %% [markdown]
# # Introduction
#
# The first test of your new data exploration skills uses data describing crime in the city of Chicago.
#
# Before you get started, run the following cell. It sets up the automated feedback system to review your answers.

# %%
# Set up feedack system
from learntools.core import binder
binder.bind(globals())
from learntools.sql.ex1 import *
print("Setup Complete")

# %% [markdown]
# Use the next code cell to fetch the dataset.

# %%
from google.cloud import bigquery

# Create a "Client" object
client = bigquery.Client()

# Construct a reference to the "chicago_crime" dataset
dataset_ref = client.dataset("chicago_crime", project="bigquery-public-data")

# API request - fetch the dataset
dataset = client.get_dataset(dataset_ref)

# %% [markdown]
# # Exercises
#
# ### 1) Count tables in the dataset
#
# How many tables are in the Chicago Crime dataset?

# %%
# Write the code you need here to figure out the answer

tables = list(client.list_tables(dataset))

for i in tables:
    print(i.table_id)

# %%
num_tables = len(tables)  # Store the answer as num_tables and then run this cell

# Check your answer
q_1.check()

# %% [markdown]
# For a hint or the solution, uncomment the appropriate line below.

# %%
# q_1.hint()
# q_1.solution()

# %% [markdown]
# ### 2) Explore the table schema
#
# How many columns in the `crime` table have `TIMESTAMP` data?

# %%
# Write the code to figure out the answer

crime_table_ref = dataset_ref.table("crime")

crime_table = client.get_table(crime_table_ref)

# just make directly into dataframe and preview from there, ok nvm too much stuff

# crime_df = client.list_rows(crime_table).to_dataframe()

# crime_df.shape()    

# using list comprehension, casting the elements in the list to str to filter for TIMESTAMP
ls = list(crime_table.schema)

has_timestamp = [k for k in ls if 'TIMESTAMP' in str(k)]

len(has_timestamp)

# %%
num_timestamp_fields = len(has_timestamp) # Put your answer here

# Check your answer
q_2.check()

# %% [markdown]
# For a hint or the solution, uncomment the appropriate line below.

# %%
q_2.hint()
q_2.solution()

# %% [markdown]
# ### 3) Create a crime map
#
# If you wanted to create a map with a dot at the location of each crime, what are the names of the two fields you likely need to pull out of the `crime` table to plot the crimes on a map?

# %%
# Write the code here to explore the data so you can find the answer
# it's probably something like lat long

for i in ls:
    print(i)

# %%
client.list_rows(crime_table, max_results=5).to_dataframe()

# %%
fields_for_plotting = ['x_coordinate', 'y_coordinate'] # Put your answers here

# Check your answer
q_3.check()

# %% [markdown]
# For a hint or the solution, uncomment the appropriate line below.

# %%
q_3.hint()
q_3.solution()

# %% [markdown]
# Thinking about the question above, there are a few columns that appear to have geographic data. Look at a few values (with the `list_rows()` command) to see if you can determine their relationship.  Two columns will still be hard to interpret. But it should be obvious how the `location` column relates to `latitude` and `longitude`.

# %%
# Scratch space for your code

# %% [markdown]
# # Keep going
#
# You've looked at the schema, but you haven't yet done anything exciting with the data itself. Things get more interesting when you get to the data, so keep going to **[write your first SQL query](https://www.kaggle.com/dansbecker/select-from-where).**

# %% [markdown]
# ---
# **[SQL Home Page](https://www.kaggle.com/learn/intro-to-sql)**
#
#
#
#
#
# *Have questions or comments? Visit the [Learn Discussion forum](https://www.kaggle.com/learn-forum/161314) to chat with other Learners.*
